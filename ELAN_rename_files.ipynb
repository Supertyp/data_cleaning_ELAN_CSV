# %%
import os

def rename_files_in_bulk(directory_path, old_prefix, new_prefix):
    try:
        # Iterate through files in the directory
        for filename in os.listdir(directory_path):
            old_file_path = os.path.join(directory_path, filename)

            # Check if the file starts with the specified old prefix
            if filename.startswith(old_prefix):
                new_filename = filename.replace(old_prefix, new_prefix)
                new_file_path = os.path.join(directory_path, new_filename)

                # Rename the file
                os.rename(old_file_path, new_file_path)
                print(f"Renamed: {filename} to {new_filename}")

    except Exception as e:
        print(f"Error renaming files: {e}")

# Example usage
#directory_path = 'C:/Users/barth/Documents/LDACA\data_cleaning/AAE/AusESL_internal_after_doublespace'
directory_path = 'C:/Users/barth/Documents/LDACA\data_cleaning/AAE/audio'
old_prefix = 'AAE_'
new_prefix = 'AusESL_'

rename_files_in_bulk(directory_path, old_prefix, new_prefix)
# Out:
# Renamed: AAE_MF_002_Stella_anon.wav to AusESL_MF_002_Stella_anon.wav
# Renamed: AAE_MF_006_Tanya_anon.wav to AusESL_MF_006_Tanya_anon.wav
# Renamed: AAE_MF_008_Kelsey_anon.wav to AusESL_MF_008_Kelsey_anon.wav
# Renamed: AAE_MF_009_Joyce_anon.wav to AusESL_MF_009_Joyce_anon.wav
# Renamed: AAE_MF_011_Rosa_anon.wav to AusESL_MF_011_Rosa_anon.wav
# Renamed: AAE_MF_012_Ruby_anon.wav to AusESL_MF_012_Ruby_anon.wav
# Renamed: AAE_MF_022_Mei_anon.wav to AusESL_MF_022_Mei_anon.wav
# Renamed: AAE_MF_024_Liu_anon.wav to AusESL_MF_024_Liu_anon.wav
# Renamed: AAE_MF_029_Ning_anon.wav to AusESL_MF_029_Ning_anon.wav
# Renamed: AAE_MF_036_Liling_anon.wav to AusESL_MF_036_Liling_anon.wav
# Renamed: AAE_MF_037_Mingzhu_anon.wav to AusESL_MF_037_Mingzhu_anon.wav
# Renamed: AAE_MF_038_Xiulan_anon.wav to AusESL_MF_038_Xiulan_anon.wav
# Renamed: AAE_MF_043_Lanfen_anon.wav to AusESL_MF_043_Lanfen_anon.wav
# Renamed: AAE_MF_045_Yanyu_anon.wav to AusESL_MF_045_Yanyu_anon.wav
# Renamed: AAE_MF_048_Li_Rong_anon.wav to AusESL_MF_048_Li_Rong_anon.wav
# Renamed: AAE_MF_049_Jennifer_anon.wav to AusESL_MF_049_Jennifer_anon.wav
# Renamed: AAE_MF_053_Jia_anon.wav to AusESL_MF_053_Jia_anon.wav
# Renamed: AAE_MF_055_Daiyu_anon.wav to AusESL_MF_055_Daiyu_anon.wav
# Renamed: AAE_MF_061_Suyin_anon.wav to AusESL_MF_061_Suyin_anon.wav
# Renamed: AAE_MM_013_Yin_anon.wav to AusESL_MM_013_Yin_anon.wav
# Renamed: AAE_MM_016_Carl_anon.wav to AusESL_MM_016_Carl_anon.wav
# Renamed: AAE_MM_039_Bojing_anon.wav to AusESL_MM_039_Bojing_anon.wav
# Renamed: AAE_MM_042_Lawrence_anon.wav to AusESL_MM_042_Lawrence_anon.wav
# Renamed: AAE_MM_044_Xiaobo_anon.wav to AusESL_MM_044_Xiaobo_anon.wav
