# %%
import os
import xml.etree.ElementTree as ET

def remove_double_spaces_from_xml(xml_file_path, output_folder):
    try:
        # Parse the XML file
        tree = ET.parse(xml_file_path)
        root = tree.getroot()

        # Function to remove double spaces from text values
        def remove_double_spaces(element):
            if element.text is not None:
                element.text = element.text.replace("  ", " ")

            for child in element:
                remove_double_spaces(child)
            
            

        # Remove double spaces from the root element
        remove_double_spaces(root)

        # Save the modified XML to the output folder
        output_file_path = os.path.join(output_folder, os.path.basename(xml_file_path))
        tree.write(output_file_path, encoding="utf-8", xml_declaration=True)

    except Exception as e:
        print(f"Error processing {xml_file_path}: {e}")

# Example usage
input_folder_path = 'C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output'
output_folder_path = 'C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Process each XML file in the input folder
for xml_file_path in os.listdir(input_folder_path):
    if xml_file_path.endswith(".eaf"):
        xml_file_path_full = os.path.join(input_folder_path, xml_file_path)
        remove_double_spaces_from_xml(xml_file_path_full, output_folder_path)
        print(f"File {xml_file_path_full} processed and saved to {output_folder_path}")
# Out:
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_002_Stella_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_006_Tanya_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_008_Kelsey_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_009_Joyce_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_011_Rosa_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_012_Ruby_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_022_Mei_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_024_Liu_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_029_Ning_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_036_Liling_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_037_Mingzhu_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_038_Xiulan_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_043_Lanfen_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_045_Yanyu_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_048_Li Rong_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_049_Jennifer_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_053_Jia_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_055_Daiyu_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MF_061_Suyin_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_013_Yin_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_016_Carl_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_039_Bojing_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_042_Lawrence_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_044_Xiaobo_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_063_Shirong_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_064_Yongrui_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_066_Bolin_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_MM_067_Yunru_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_001_Anastasia_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_004_Mila_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_007_Melania_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_010_Natasha_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_017_Alenka_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_018_Lidia_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_019_Rita_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_020_Victoria_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_021_Elena_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_023_Valerie_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_025_Mikhaila_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_026_Mischa_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_028_Karina_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_030_Ivana_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_031_Nikola_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_032_Ingrid_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_033_Alina_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_034_Yana_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RF_035_Malvina_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_003_Sergey_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_040_Stefan_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_051_Anton_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_052_Stas_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_054_Markov_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_056_Andrei_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_057_Stepan_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_058_Demid_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_059_Adrik_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
# File C:/Users/barth/Documents/LDACA\data_cleaning/AAE/cleaned_after_output\AAE_RM_065_Slava_anon.eaf processed and saved to C:/Users/barth/Documents/LDACA\data_cleaning/AAE/doublespaces_removed_after_cleaned
